# %%
import mne
import pandas as pd
import numpy as np

# %%
raw = mne.io.read_raw_edf('../test_data/S001R03.edf')
# Out:
# Extracting EDF parameters from d:\gitrepos\papers\paper_zebendelib\test_data\S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
data =raw.get_data().T

# %%
df = pd.DataFrame(data, columns=raw.info['ch_names']).to_csv(
    '../test_data/data.csv', index=False)

# %%
df
# Out:
#            Fc5.      Fc3.      Fc1.      Fcz.      Fc2.      Fc4.      Fc6.  \
# 0     -0.000057 -0.000013 -0.000015 -0.000012 -0.000013 -0.000008 -0.000040
# 1     -0.000049 -0.000011 -0.000010 -0.000012 -0.000019 -0.000024 -0.000058
# 2     -0.000055 -0.000017 -0.000016 -0.000019 -0.000024 -0.000029 -0.000066
# 3     -0.000073 -0.000042 -0.000040 -0.000037 -0.000037 -0.000040 -0.000071
# 4     -0.000087 -0.000053 -0.000052 -0.000051 -0.000045 -0.000043 -0.000071
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19996  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19997  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19998  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19999  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# ...
